# %%
# import library for data manipulation
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the Data Set.

# %%
df = pd.read_csv('heart.csv')

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### Firstly, we will explore how the feature scale influences the algorithm’s performance. Train an SVM model on 4 versions of the Data Set:

# %%
# import the libraries
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split

# %%
# split the dataset into features (X) and target (y)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
# split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# __- Initial one.__

# %%
# train and evaluate an SVM model on the initial dataset
svm = SVC(kernel='linear', C=1)

svm.fit(X_train, y_train)

initialScore = svm.score(X_test, y_test)
print("Accuracy on initial dataset:", initialScore)
# Out:
# Accuracy on initial dataset: 0.819672131147541

# %% [markdown]
# __- The one passed through the StandardScaler.__

# %%
# train and evaluate an SVM model on the dataset passed through the StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svm.fit(X_train_scaled, y_train)

StandardScalerScore = svm.score(X_test_scaled, y_test)
print("Accuracy on StandardScaler dataset:", StandardScalerScore)
# Out:
# Accuracy on StandardScaler dataset: 0.819672131147541

# %% [markdown]
# __- The one passed through the MinMaxScaler.__

# %%
# train and evaluate an SVM model on the dataset passed through the MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svm.fit(X_train_scaled, y_train)

MinMaxScalerScore = svm.score(X_test_scaled, y_test)
print("Accuracy on MinMaxScaler dataset:", MinMaxScalerScore)
# Out:
# Accuracy on MinMaxScaler dataset: 0.8360655737704918

# %% [markdown]
# __- The one passed through the MaxAbsScaler.__

# %%
# train and evaluate an SVM model on the dataset passed through the MaxAbsScaler
scaler = MaxAbsScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

svm.fit(X_train_scaled, y_train)

MaxAbsScaler = svm.score(X_test_scaled, y_test)
print("Accuracy on MaxAbsScaler dataset:", MaxAbsScaler)
# Out:
# Accuracy on MaxAbsScaler dataset: 0.819672131147541

# %% [markdown]
# ### Create the following table in pandas and compare the results. Comment them: Initial standard scaler min max scaler max abs scaler
#
# This code first splits the dataset into features (X) and target (y). Then it splits the data into training and test sets. After that, it initializes an SVM model, trains it on the initial dataset, and evaluates its accuracy on the test set. Then it applies each of the scalers (StandardScaler, MinMaxScaler and MaxAbsScaler) on the train and test sets separately, retrains the model and calculates the accuracy on the corresponding test set.
# It is worth noting that, the accuracy of the model can be affected by the train-test split, and the parameter selection of the model. In practice, you would want to use cross-validation to get a more robust estimate of the model's performance.

# %%
# create a table with the output of the different versions of the dataset
data = {'Scaler': ['Initial', 'StandardScaler', 'MinMaxScaler', 'MaxAbsScaler'],
        'Accuracy': [initialScore, StandardScalerScore, MinMaxScalerScore, MaxAbsScaler]}

table = pd.DataFrame(data)

print(table)
# Out:
#            Scaler  Accuracy
# 0         Initial  0.819672
# 1  StandardScaler  0.819672
# 2    MinMaxScaler  0.836066
# 3    MaxAbsScaler  0.819672

# %% [markdown]
# ### Usually, SVMs use some Kernel to move the data to another space where linear planes separate the classes. In this task, you will have to explore how different kernels influence the decision boundary. Create the plots of decision boundary for the following kernels:
#
# - linear
# - poly
# - rbf
# - sigmoid

# %%
from sklearn.decomposition import PCA

# Apply PCA to the dataset
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train)

# create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs = axs.ravel()

# train an SVM model for each kernel and plot the decision boundary
for i, kernel in enumerate(kernels):
    svm = SVC(kernel=kernel, C=1, degree=3)
    svm.fit(X_pca, y_train)
    axs[i].scatter(X_pca[:, 0], X_pca[:, 1], c=y_train)
    axs[i].set_title(kernel)
    axs[i].set_xlim(-3, 3)
    axs[i].set_ylim(-3, 3)

    # create a meshgrid and evaluate the model on it
    xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
    Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the decision boundary
    axs[i].contour(xx, yy, Z, levels=[0], linewidths=2, colors='black')
plt.show()

# %% [markdown]
# ### Plot them all together in a combined plot, compare them, and express some conclusions.

# %%
# Apply PCA to the dataset
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train)

# create a figure and subplots
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_pca[:, 0], X_pca[:, 1], c=y_train)
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)

# train an SVM model for each kernel and plot the decision boundary
for kernel in kernels:
    svm = SVC(kernel=kernel, C=1, degree=3)
    svm.fit(X_pca, y_train)

    # create a meshgrid and evaluate the model on it
    xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
    Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the decision boundary
    ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black', label=kernel)

plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_222264\27858846.py:22: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black', label=kernel)
# C:\Users\user\AppData\Local\Temp\ipykernel_222264\27858846.py:22: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black', label=kernel)
# C:\Users\user\AppData\Local\Temp\ipykernel_222264\27858846.py:22: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black', label=kernel)
# C:\Users\user\AppData\Local\Temp\ipykernel_222264\27858846.py:22: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black', label=kernel)
# ...

# %%
# Apply PCA to the dataset
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train)

# create a figure and subplots
fig, ax = plt.subplots(figsize=(10, 10))

# train an SVM model for each kernel and plot the decision boundary
for kernel in kernels:
    svm = SVC(kernel=kernel, C=1, degree=3)
    svm.fit(X_pca, y_train)

    # create a meshgrid and evaluate the model on it
    xx, yy = np.meshgrid(np.linspace(-3, 3, 500), np.linspace(-3, 3, 500))
    Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.scatter(xx, yy, c=Z, label=kernel)

plt.legend(loc="best")

plt.show()

# %% [markdown]
# #### aici ar trebuie sa fie conculizii
# insa am intrebari ce este SVM și cum funcționeză?
# ce este hyper plane?
# ce este || W ||?
# de ce am avea nevoie de separarea data:
#
# - linear
# - poly
# - rbf
# - sigmoid

# %% [markdown]
# ### TESTE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
# from sklearn.datasets import make_classification

# generate a toy dataset
X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                            n_clusters_per_class=1, class_sep=1, random_state=0)

# define a list of kernels to test
kernels = ['linear', 'poly', 'rbf', 'sigmoid']

# create a figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs = axs.ravel()

# train an SVM model for each kernel and plot the decision boundary
for i, kernel in enumerate(kernels):
    svm = SVC(kernel=kernel, C=1, degree=3)
    svm.fit(X, y)
    axs[i].scatter(X[:, 0], X[:, 1], c=y)
    axs[i].set_title(kernel)
    axs[i].set_xlim(-3, 3)
    axs[i].set_ylim(-3, 3)

    # create a meshgrid and evaluate the model on it
    xx, yy = np.meshgrid(np.linspace(-3, 3, 500),
                         np.linspace(-3, 3, 500))
    Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the decision boundary
    axs[i].contour(xx, yy, Z, levels=[0], linewidths=2, colors='black')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
# from sklearn.datasets import make_classification

# generate a toy dataset
X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                            n_clusters_per_class=1, class_sep=1, random_state=0)

# define a list of kernels to test
kernels = ['linear', 'poly', 'rbf', 'sigmoid']

# create a figure and subplots
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X[:, 0], X[:, 1], c=y)
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)

# train an SVM model for each kernel and plot the decision boundary
for kernel in kernels:
    svm = SVC(kernel=kernel, C=1, degree=3)
    svm.fit(X, y)
    # create a meshgrid and evaluate the model on it
    xx, yy = np.meshgrid(np.linspace(-3, 3, 500),
                         np.linspace(-3, 3, 500))
    Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # plot the decision boundary
    ax.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black')
#     ax.legend(kernel)

# plt.legend() - erorr cu display la legedend
plt.show()

# %% [markdown]
# Acest cod aplică PCA setului de date și utilizează primele două componente principale ca caracteristici pentru a antrena modelul SVM, apoi trasează granița de decizie a modelului pentru fiecare nucleu pe aceeași figură și folosește argumentul etichetei pentru a distinge fiecare nucleu.
#
#
# Puteți compara limita de decizie a fiecărui nucleu, nucleul liniar are o limită de decizie liniară, în timp ce nucleele polinomiale și RBF pot crea limite de decizie mai complexe.
#
# Nucleul sigmoid creează o graniță de decizie care este o combinație între o linie dreaptă și o funcție sigmoidă.
#
# Este de remarcat faptul că SVM-ul cu nucleu polinomial este mai sensibil la valoarea parametrului de grad care este setat la 3 în codul de mai sus, este o practică bună să utilizați validarea încrucișată pentru a găsi parametrul de grad optim pentru acest nucleu.
#
# De asemenea, SVM cu nucleu RBF este sensibil la valoarea parametrului gamma, care ar trebui, de asemenea, optimizat folosind validarea încrucișată.
#
# De asemenea, este de remarcat faptul că, prin ajustarea parametrului de regularizare C și a parametrului gamma al nucleului RBF, este posibil să se realizeze o limită de decizie mai complexă care poate separa mai bine clasele.
