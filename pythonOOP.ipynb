# %% [markdown]
# Week 1
# Tasks for Object Oriented Programming
# 1. Choose a topic to create a project on.
# 2. Your project should contain the following stuff:
# - A class with the following criteria:
#     * an initialization method (some fields should be private and/or protected);
#     * some methods with different accessing criteria (public protected, private);
#     * fields should be of minimum 3 different data types.
# - Two or more classes that inheirit the the basic class described above and should contain some overriden or overloaded methods from the parent class.
# 3. Create objects of each type described in your project.
# 4. Show the differences between the objects of different types (their creation, usage, output, so on).
# 5. Create a GitHub repository whaere you will be posting all homeworks during your studying period and send me the link to it.
# 6. Deadline for submission: 4.11.2022, 21:00.

# %%
# main (parent) class
class Person:
    
    # public data member - none == null 
    name = None
    patronymic = None
    # protected data member
    _age = None
    _months = None
    _height = None
    
    
    #private data memeber
    __surname = None
    
    
    # constructor for our object
    def __init__(self, name, surname, age, months):
        self.name = name
        self.__surname = surname
        self._age = age
        self._months = months 


    # public member function
    def displayPublicMembers(self):
        
        # accesing public data member
        print("Public Data Member: ", self.name)
    
    
    # protected member function
    def _displayProtectedMembers(self):
        
        # accesing private data members
        print("Proctected Data Member Age - Year: ", self._age)
        print("Proctected Data Member Age - Months", self._months)
        # protected member function
        
    def _displayProtectedMembersOne(self):

        # accesing private data members
        print("Proctected Data Member Age - Year One: ", self._age)
        print("Proctected Data Member Height One: ", self._height, "m")

   
    # private member function
    def __displayPrivateMembers(self):
        
        # accesing protectect data members
        print("Private Data Member:", self.__surname)
    
    # call the function that display the private data member
    def accessPrivateMembers(self): 
        
        # accesing private member function
        self.__displayPrivateMembers()
    
    # call the function that display the private data member
    def accessPrivateMembers(self): 
        
        # accesing private member function
        self.__displayPrivateMembers()
        


        
# derived(child) class
class ChildFromMain( Person ):
   
    # constructor for the class
    def __init__(self, name, surname, age, months):
        Person.__init__(self, name, surname, age, months)
    
    
    # public member function
    def accessProtectedMembers(self):
        # accesing protected member fucntion of super class
        self._displayProtectedMembers()
        
      
    
class ChildFromChild( ChildFromMain, Person ):
    # overloading
    # constructor for the class
    
    # overriding/overloading 
    # constructor for our object
    def __init__(self, name, patronymic, age, height):
        self.name = name
        self.patronymic = patronymic
        self._age = age
        self._height = height

    # overloading
    # public member function
    def accessProtectedMembers(self):
        # accesing protected member fucntion of super class
        self._displayProtectedMembersOne()
    
    #overloading 
    # public member function
    def displayPublicMembers(self):
        
        # accesing public data member
        print("Public Data Member: ", self.name)
        print("Public Data Member: ", self.patronymic)
    
# creating objects of the derived class
obj = ChildFromMain("Seba", 'Barimb', 21, 6.0)
objOne = ChildFromChild("Seba", "GH", 21, 1.8)


# calling public member function of the class
obj.displayPublicMembers()
obj.accessPrivateMembers()
obj.accessProtectedMembers()

print('\n')
objOne.displayPublicMembers()
objOne.accessProtectedMembers()





# object can access protected member
# print("Object is accesing protected member: ", obj._age)
# Out:
# Public Data Member:  Seba
# Private Data Member: Barimb
# Proctected Data Member Age - Year:  21
# Proctected Data Member Age - Months 6.0
#
#
# Public Data Member:  Seba
# Public Data Member:  GH
# Proctected Data Member Age - Year One:  21
# Proctected Data Member Height One:  1.8 m
